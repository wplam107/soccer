# %%
import numpy as np
import pandas as pd
import pickle

# %%
# Load pickled data
with open('events.p', 'rb') as f:
    events = pickle.load(f)

with open('teams.p', 'rb') as f:
    teams = pickle.load(f)
    
with open('matches.p', 'rb') as f:
    matches = pickle.load(f)
    
with open('players.p', 'rb') as f:
    players = pickle.load(f)

# %%
pd.DataFrame(matches)
# Out:
#      match_id        date  time                      location  \
# 0     2500089  2018-05-13  1400           Burnley, Lancashire
# 1     2500090  2018-05-13  1400                        London
# 2     2500091  2018-05-13  1400  Huddersfield, West Yorkshire
# 3     2500092  2018-05-13  1400                     Liverpool
# 4     2500093  2018-05-13  1400                    Manchester
# ..        ...         ...   ...                           ...
# 375   2499723  2017-08-12  1400                     Liverpool
# 376   2499726  2017-08-12  1400        Southampton, Hampshire
# 377   2499728  2017-08-12  1400                 West Bromwich
# 378   2499727  2017-08-12  1130                       Watford
# 379   2499719  2017-08-11  1845                        London
#
#                 home_team               away_team   score  temp_c  wind_kmph  \
# 0                 Burnley         AFC Bournemouth  (1, 2)      14         17
# 1          Crystal Palace    West Bromwich Albion  (2, 0)      15         10
# 2       Huddersfield Town                 Arsenal  (0, 1)      15         16
# 3               Liverpool  Brighton & Hove Albion  (4, 0)      14          8
# 4       Manchester United                 Watford  (1, 0)      15         14
# ..                    ...                     ...     ...     ...        ...
# 375               Everton              Stoke City  (1, 0)      16         20
# 376           Southampton            Swansea City  (0, 0)      18         21
# 377  West Bromwich Albion         AFC Bournemouth  (1, 0)      20         19
# 378               Watford               Liverpool  (3, 3)      19         19
# 379               Arsenal          Leicester City  (4, 3)      19         15
#
#      precip_mm
# 0          0.0
# 1          0.2
# 2          0.0
# 3          0.0
# 4          0.0
# ..         ...
# 375        0.5
# 376        0.0
# 377        0.4
# 378        0.0
# 379        0.0
#
# [380 rows x 10 columns]
